# %% [markdown]
# # Binomial Distribution

# %% [markdown]
# #### It is the probability distrubiton that used when dealing with probability of success k times after independent trials n times.

# %% [markdown]
# ![image.png](attachment:15d2cc64-5552-4f0b-b7a6-60662516458a.png)
