# %% [markdown]
# # Bernoulli Distribution

# %% [markdown]
# #### It is the discrete probability distrubition that used when dealing with events with two consequences like positive-negative, successfull-unsuccessfull.

# %% [markdown]
# ![image.png](attachment:7c04135d-fcd8-48ec-86b4-ca601b05ad2d.png)

# %% [markdown]
# ![image.png](attachment:d98e8eb5-cf4f-4948-ae48-8aad446dfaee.png)

# %%
from scipy.stats import bernoulli

# %%
p = 0.6
