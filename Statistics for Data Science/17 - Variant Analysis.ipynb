# %% [markdown]
# # Variant Analysis

# %% [markdown]
# #### It is a method that used when it is desired to test if there is a significant difference between means of two or more samples

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# ![image.png](attachment:541d57ef-ae2d-49f1-9484-dd7da9a7e524.png)

# %% [markdown]
# ## Test Statistics

# %% [markdown]
# ![image.png](attachment:1bb4552f-3428-4660-8bba-d594fdef7d50.png)

# %% [markdown]
# ## Assumptions

# %% [markdown]
# ### 1) Independent observations

# %% [markdown]
# ### 2) Normal Distribution

# %% [markdown]
# ### 3) Variant Homogeneity
