# %% [markdown]
# # Independent Two Sample T Test

# %% [markdown]
# ## Hyphothesis

# %% [markdown]
# ![image.png](attachment:375d4221-6d1a-4b9e-a654-c8e28784f096.png)

# %% [markdown]
# ## Test Statistics
# #### There are 3 types of calculation for independent two sample t test.

# %% [markdown]
# #### 1) If count of samples are same and varients are homogeneous

# %% [markdown]
# ![image.png](attachment:e4f3c52d-1fce-4bc7-be87-af708b41518f.png)

# %% [markdown]
# #### 2) If count of samples are different and varients are homogeneous

# %% [markdown]
# ![image.png](attachment:da5b165b-d0d5-4ee7-a7e4-fe104b37bb94.png)

# %% [markdown]
# #### 3) If count of samples are different and varients are not homogeneous

# %% [markdown]
# ![image.png](attachment:000602ca-73d1-491e-9312-9fbaca215be3.png)

# %% [markdown]
# ## Assumptions

# %% [markdown]
# #### 1) Normality

# %% [markdown]
# #### 2) Varient Homogeneity
