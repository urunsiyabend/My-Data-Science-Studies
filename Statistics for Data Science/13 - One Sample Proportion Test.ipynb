# %% [markdown]
# # One Sample Proportion Test

# %% [markdown]
# #### It is the test that used when testing proportional expressions.

# %% [markdown]
# ![image.png](attachment:dbfb9fd6-d222-41f7-ae0b-b571436a3d55.png)

# %% [markdown]
# ![image.png](attachment:0fce10f7-1692-4636-b8ad-4b4e9f835d50.png)

# %% [markdown]
# ## Assumptions

# %% [markdown]
# ![image.png](attachment:4ee10bd8-d404-4832-b5c3-b11658c80802.png)
