# %% [markdown]
# # Two Sample Proportion Test

# %% [markdown]
# #### It is the test that used for comparing two samples.

# %% [markdown]
# ## Hypotheses

# %% [markdown]
# ![image.png](attachment:baecc30d-b37f-472f-b6b8-49762bdafa9c.png)

# %% [markdown]
# ## Test Statistics

# %% [markdown]
# ![image.png](attachment:41136e97-1c44-4c4d-bbde-2c87fde60d5f.png)

# %% [markdown]
# ## Assumptions

# %% [markdown]
# #### n1 > 30
# #### n2 > 30
