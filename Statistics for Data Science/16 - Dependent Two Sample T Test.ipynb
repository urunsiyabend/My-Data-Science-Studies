# %% [markdown]
# # Dependent Two Sample T Test

# %% [markdown]
# ### It is the test that used when it is desired to compare sampling means of dependent groups.

# %% [markdown]
# ![image.png](attachment:fa38a325-1f35-47de-b1cd-a938167ef64d.png)

# %% [markdown]
# ![image.png](attachment:34b2080e-c1af-4fb0-bdc6-9155052f785e.png)

# %% [markdown]
# ## Assumptions

# %% [markdown]
# ### 1) Normality

# %% [markdown]
# ### 2) Varient Homogeneity
