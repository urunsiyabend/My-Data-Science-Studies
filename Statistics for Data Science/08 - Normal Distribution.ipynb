# %% [markdown]
# # Normal Distribution

# %% [markdown]
# #### It is the probability distrubiton that used when it is desired to calculate the probability of continuous random variables known for being normal-distributed.

# %% [markdown]
# ![image.png](attachment:3c9d67bf-4e06-464b-a380-e0784c26a0e9.png)
