# %% [markdown]
# # One Sample T Test

# %% [markdown]
# #### It is a parametric test for testing if there is a statistical significance difference between presumptive value and population mean

# %% [markdown]
# ## Hypotheses

# %% [markdown]
# ![image.png](attachment:bd9c4c48-5c02-44c7-8ccc-eb5a6e18d274.png)

# %% [markdown]
# ## Test Statistics

# %% [markdown]
# ![image.png](attachment:6faa1337-9fcc-4b79-b813-3264e3dc3561.png)

# %% [markdown]
# #### 1) If standart deviation of population is known, we use z statistic.

# %% [markdown]
# #### 2) If it is not known, if n > 30 we use z statistic. If n < 30 we use t statistic.
