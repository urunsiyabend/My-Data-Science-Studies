# %% [markdown]
# # Poisson Distribution

# %% [markdown]
# #### It is the probability distribution used when it is desired to calculate the probability of rare events in a specific time interval.

# %% [markdown]
# ##### What is the probability of entering 5 incorrect notes out of 5000 notes.

# %% [markdown]
# ![image.png](attachment:328dba61-6447-43fb-b84c-6a7e058e61fa.png)

# %% [markdown]
# **Result:** 0,00000218
