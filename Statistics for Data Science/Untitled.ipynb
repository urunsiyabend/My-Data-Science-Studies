# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# ### The statistical method that used to determine intensity and direction of relation between variables.

# %% [markdown]
# ![image.png](attachment:4ed15af8-fabe-439c-b7ac-1d86f628d630.png)

# %% [markdown]
# ## Testin the Significant of Correlation

# %% [markdown]
# ### Hypotheses

# %% [markdown]
# ![image.png](attachment:4a665d47-3d93-4e6f-aa81-7dc4db16a9bb.png)

# %% [markdown]
# ##### H0: There is no correlation between variables.

# %% [markdown]
# ### Test Statistics

# %% [markdown]
# ![image.png](attachment:60f5b461-df19-402b-98b9-f078cbe51e3f.png)

# %% [markdown]
# ![image.png](attachment:b9827a0d-8b94-45dd-a70b-d553fd56e207.png)
