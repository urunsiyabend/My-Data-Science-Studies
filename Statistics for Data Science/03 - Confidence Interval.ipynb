# %% [markdown]
# # Calculating Confidence Interval

# %% [markdown]
# **Step 1**: Determine n, mean and standart deviation.

# %% [markdown]
# n = 100, mean = 180, standart deviation = 40

# %% [markdown]
# **Step 2**: Decide the confidence interval. (95 - 99)

# %% [markdown]
# Calculate Z-table value (1,96 - 2,57)

# %% [markdown]
# **Step 3**: Calculate the confidence interval based on above values.

# %% [markdown]
# ![image.png](attachment:6bcc4437-a0e1-49dc-b7d5-78a91985cfbe.png)

# %% [markdown]
# **Result**: 180 ± 8,84      -->          (172 - 188)
