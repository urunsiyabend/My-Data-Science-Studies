# %% [markdown]
# # Hypotheses and Hypothesis Types

# %% [markdown]
# ![image.png](attachment:2e3c50e1-24f3-4e18-aff4-ab30d208ee76.png)

# %% [markdown]
# ![image.png](attachment:b3120214-5292-4070-afb7-7dffbd31f0af.png)!
