# %% [markdown]
# # Model ValidationMethods

# %% [markdown]
# ## Holdout Method

# %% [markdown]
# ![image.png](attachment:1e38fde7-cdf3-4138-b430-c1846fcd94f7.png)

# %% [markdown]
# ## K-Fold Cross Validation

# %% [markdown]
# ![image.png](attachment:b30cce2d-927b-44be-8326-5c9b9107407f.png)

# %% [markdown]
# ## Leave One Out Cross Validation

# %% [markdown]
# ![image.png](attachment:ab5c5428-9c5b-42a6-8c1e-50cd6f82e5f3.png)

# %% [markdown]
# ## Bootstrap Validation

# %% [markdown]
# ![image.png](attachment:909a4e93-9e6f-4301-ad19-c87f827d435a.png)
