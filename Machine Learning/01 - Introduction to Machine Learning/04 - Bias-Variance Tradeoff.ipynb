# %% [markdown]
# # Bias Variance Tradeoff

# %% [markdown]
# ![image.png](attachment:2b5f5cbd-2950-408b-b0ec-58f0a32c9e47.png)

# %% [markdown]
# ![image.png](attachment:c039f605-2fd9-44c1-aaf2-34966e1a8100.png)
