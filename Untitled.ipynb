# %% [markdown]
# # Try

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("./Datasets/odev_not.xls")

# %%
df
# Out:
#         No  Öğrenci No                                            Ad Soyad  \
# 0      NaN          NaN                                                NaN
# 1      1.0  05180000933                                      JAWAD SHAFAIE
# 2      2.0  05190000050                                     RIZA KARADEMİR
# 3      3.0  05190000056                                  ONUR DENİZ YILMAZ
# 4      4.0  05190000058                                      DAMLA KARATAŞ
# ..     ...          ...                                                ...
# 163  163.0  05210001145                                  YUSUF MERT ÇINKIR
# 164  164.0  93210000233                                      İREM ÜGRETİCİ
# 165  165.0  93210000235                                     ORÇUN ZORBOZAN
# 166    NaN          NaN                                                NaN
# 167    NaN       * Not:  %50 ve %25 kesinti, kısmen kopya olduğu tespit...
#
# ...

# %%
df.head()
# Out:
#     No  Öğrenci No            Ad Soyad                 Algoritma (50p)  \
# 0  NaN          NaN                NaN  Sabit (constant) kullanma (1p)
# 1  1.0  05180000933      JAWAD SHAFAIE                             0.5
# 2  2.0  05190000050     RIZA KARADEMİR                               1
# 3  3.0  05190000056  ONUR DENİZ YILMAZ                             0.5
# 4  4.0  05190000058      DAMLA KARATAŞ                             0.5
#
#                              Unnamed: 4     Unnamed: 5  \
# 0  Anlamlı değişken/sabit isimleri (2p)  Girdiler (3p)
# 1                                   0.5              0
# 2                                     2              3
# 3                                     1              3
# 4                                     2              3
#
#                                Unnamed: 6  \
# 0  Müşteri Borcu (Gelir) Hesaplaması (4p)
# 1                                       4
# 2                                       4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   No                                        165 non-null    float64
#  1   Öğrenci No                                166 non-null    object
#  2   Ad Soyad                                  166 non-null    object
#  3   Algoritma (50p)                           159 non-null    object
#  4   Unnamed: 4                                159 non-null    object
#  5   Unnamed: 5                                159 non-null    object
#  6   Unnamed: 6                                159 non-null    object
#  7   Unnamed: 7                                159 non-null    object
#  8   Unnamed: 8                                159 non-null    object
#  9   Unnamed: 9                                159 non-null    object
# ...

# %%
df["Algoritma (50p)"]
# Out:
# 0      Sabit (constant) kullanma (1p)
# 1                                 0.5
# 2                                   1
# 3                                 0.5
# 4                                 0.5
#                     ...
# 163                                 1
# 164                                 1
# 165                               0.5
# 166                               NaN
# 167                               NaN
# Name: Algoritma (50p), Length: 168, dtype: object
