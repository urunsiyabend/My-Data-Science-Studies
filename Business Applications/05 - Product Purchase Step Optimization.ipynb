# %% [markdown]
# # Product Purchase Step Optimization

# %% [markdown]
# **Problem:**
# * There are 5 steps after adding product to cart and one of them is be questioned
#
# **Details:**
# * It is desired set each step duration to 20 seconds and step 4 is be questioned.
# * 100 samples are taken for testing this statement.
# * Standart deviation of sample is 5 seconds and mean of sample is 19 seconds.

# %% [markdown]
# ### **Step 1**: Hypothesizing and determining directions
#
# ![image.png](attachment:c05f2c2c-5198-406c-8427-b0e05c9dfe7a.png)
#
# ### **Step 2**: Specifing significance level and table value
#
# ![image.png](attachment:52039f04-aad6-4d39-a5ac-c787efbb58e4.png)
#
# Ztable probability value: 0,5 - 0,025 = 0,475
#
# Ztable critic value = -/+ 1,96
#
# ### **Step 3**: Specifing and calculating test statistic
#
# ![image.png](attachment:a456905a-92fa-48b3-843d-515fb8f0567d.png)
#
# #### Zc = -2
#
# ### **Step 4**: Comparing calculated test statistic and table value that equaled to alpha
#
# If Test statistic (Zc) > Table Value <Zt>, then reject H0
#
# Zc = -2
# Zt = -1,96
#
# H0 is rejected because Ztable is greater than Zc
#
# ### **Step 5**: Explanation

# %% [markdown]
# It is rejected the hypothesis that 20 seconds was spent in step 4. So, statisticly users spent time different from 20 seconds with 95 percent confidence.
